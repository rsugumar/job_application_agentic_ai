# %%
from google.adk.runners import InMemoryRunner
from dotenv import load_dotenv


load_dotenv()
# Out:
# True

# %%
from rag.agent import rag_agent

runner = InMemoryRunner(agent=rag_agent)
response = await runner.run_debug("tell about sukumar in 10 words", verbose=True)
